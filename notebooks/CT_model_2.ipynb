# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 224
BATCH_SIZE =32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Model_2_types_cancer_bein_v2",
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 1449 files belonging to 4 classes.

# %%
import os

# Chemins des sous-dossiers
Bengin_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/Bengin"
adenocarcinoma_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/adenocarcinoma"
large_cell_carcinoma_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/large.cell.carcinoma"
squamous_cell_carcinoma_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/squamous.cell.carcinoma"

# Fonction pour compter les fichiers dans un dossier
def count_images(folder_path):
    return len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

# Compter les images dans chaque sous-dossier
Bengin_count = count_images(Bengin_folder)
adenocarcinoma_count = count_images(adenocarcinoma_folder)
large_cell_carcinoma_count = count_images(large_cell_carcinoma_folder)
squamous_cell_carcinoma_count = count_images(squamous_cell_carcinoma_folder)

# Afficher le nombre d'images dans chaque dossier
print(f"Nombre d'images dans le dossier 'Bengin' : {Bengin_count}")
print(f"Nombre d'images dans le dossier 'adenocarcinoma' : {adenocarcinoma_count}")
print(f"Nombre d'images dans le dossier 'large.cell.carcinoma' : {large_cell_carcinoma_count}")
print(f"Nombre d'images dans le dossier 'squamous.cell.carcinoma' : {squamous_cell_carcinoma_count}")
# Out:
# Nombre d'images dans le dossier 'Bengin' : 700
# Nombre d'images dans le dossier 'adenocarcinoma' : 341
# Nombre d'images dans le dossier 'large.cell.carcinoma' : 156
# Nombre d'images dans le dossier 'squamous.cell.carcinoma' : 252

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, save_img

# Chemin vers le dossier contenant les 120 images
input_dir = '/content/drive/MyDrive/Model_2_types_cancer_bein_v2/squamous.cell.carcinoma'
output_dir = '/content/drive/MyDrive/Model_2_types_cancer_bein_v2/squamous.cell.carcinoma'

# Créer le dossier de sortie s'il n'existe pas
os.makedirs(output_dir, exist_ok=True)

# Paramètres d'augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Charger toutes les images existantes et redimensionner si nécessaire
images = []
for img_file in os.listdir(input_dir):
    img_path = os.path.join(input_dir, img_file)
    img = load_img(img_path)  # Load the image

    # Check if the image needs resizing
    if img.size != (IMAGE_SIZE, IMAGE_SIZE):
        img = img.resize((IMAGE_SIZE, IMAGE_SIZE))  # Resize if necessary

    img_array = img_to_array(img)  # Convert to NumPy array
    images.append(img_array)

images = np.array(images)

# Générer des images jusqu'à atteindre 700 au total
current_count = len(images)
target_count = 350
generated_count = 0

while current_count + generated_count < target_count:
    for image in datagen.flow(images, batch_size=1, save_to_dir=output_dir, save_format='jpeg'):
        generated_count += 1
        if current_count + generated_count >= target_count:
            break

print(f"{generated_count} images générées avec succès.")
# Out:
# 98 images générées avec succès.

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, save_img

# Chemin vers le dossier contenant les 120 images
input_dir = '/content/drive/MyDrive/Model_2_types_cancer_bein_v2/large.cell.carcinoma'
output_dir = '/content/drive/MyDrive/Model_2_types_cancer_bein_v2/large.cell.carcinoma'

# Créer le dossier de sortie s'il n'existe pas
os.makedirs(output_dir, exist_ok=True)

# Paramètres d'augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Charger toutes les images existantes et redimensionner si nécessaire
images = []
for img_file in os.listdir(input_dir):
    img_path = os.path.join(input_dir, img_file)
    img = load_img(img_path)  # Load the image

    # Check if the image needs resizing
    if img.size != (IMAGE_SIZE, IMAGE_SIZE):
        img = img.resize((IMAGE_SIZE, IMAGE_SIZE))  # Resize if necessary

    img_array = img_to_array(img)  # Convert to NumPy array
    images.append(img_array)

images = np.array(images)

# Générer des images jusqu'à atteindre 700 au total
current_count = len(images)
target_count = 340
generated_count = 0

while current_count + generated_count < target_count:
    for image in datagen.flow(images, batch_size=1, save_to_dir=output_dir, save_format='jpeg'):
        generated_count += 1
        if current_count + generated_count >= target_count:
            break

print(f"{generated_count} images générées avec succès.")
# Out:
# 184 images générées avec succès.

# %%
import os

# Chemins des sous-dossiers
Bengin_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/Bengin"
adenocarcinoma_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/adenocarcinoma"
large_cell_carcinoma_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/large.cell.carcinoma"
squamous_cell_carcinoma_folder = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2/squamous.cell.carcinoma"

# Fonction pour compter les fichiers dans un dossier
def count_images(folder_path):
    return len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

# Compter les images dans chaque sous-dossier
Bengin_count = count_images(Bengin_folder)
adenocarcinoma_count = count_images(adenocarcinoma_folder)
large_cell_carcinoma_count = count_images(large_cell_carcinoma_folder)
squamous_cell_carcinoma_count = count_images(squamous_cell_carcinoma_folder)

# Afficher le nombre d'images dans chaque dossier
print(f"Nombre d'images dans le dossier 'Bengin' : {Bengin_count}")
print(f"Nombre d'images dans le dossier 'adenocarcinoma' : {adenocarcinoma_count}")
print(f"Nombre d'images dans le dossier 'large.cell.carcinoma' : {large_cell_carcinoma_count}")
print(f"Nombre d'images dans le dossier 'squamous.cell.carcinoma' : {squamous_cell_carcinoma_count}")
# Out:
# Nombre d'images dans le dossier 'Bengin' : 700
# Nombre d'images dans le dossier 'adenocarcinoma' : 341
# Nombre d'images dans le dossier 'large.cell.carcinoma' : 340
# Nombre d'images dans le dossier 'squamous.cell.carcinoma' : 350

# %%
import os
import shutil
import random

# Chemins source et cible
source_dir = "/content/drive/MyDrive/Model_2_types_cancer_bein_v2"
target_dir = "/content/drive/MyDrive/model_2_types_cancer_bein_v2_structurer"

# Crée le dossier cible s'il n'existe pas
if not os.path.exists(target_dir):
    os.makedirs(target_dir)

# Limite d'images par classe
limit_per_class = 340

for class_name in os.listdir(source_dir):
    class_dir = os.path.join(source_dir, class_name)
    if os.path.isdir(class_dir):
        # Filtrer les fichiers pour ne prendre que les images valides (ex : extensions courantes)
        images = [img for img in os.listdir(class_dir) if img.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))]

        # Vérifie qu'il y a des images dans la classe
        if not images:
            print(f"Aucune image trouvée dans la classe : {class_name}")
            continue

        # Sélectionner aléatoirement jusqu'à 1400 images
        selected_images = random.sample(images, min(len(images), limit_per_class))

        # Crée le dossier de la classe cible
        target_class_dir = os.path.join(target_dir, class_name)
        os.makedirs(target_class_dir, exist_ok=True)

        # Copier les images sélectionnées
        for image_name in selected_images:
            source_path = os.path.join(class_dir, image_name)
            target_path = os.path.join(target_class_dir, image_name)
            try:
                shutil.copy(source_path, target_path)
            except Exception as e:
                print(f"Erreur lors de la copie de {source_path} vers {target_path} : {e}")

print("Copie des images terminée.")
# Out:
# Aucune image trouvée dans la classe : .ipynb_checkpoints
# Copie des images terminée.

# %%
import os

# Chemins des sous-dossiers
Bengin_folder = "/content/drive/MyDrive/model_2_types_cancer_bein_v2_structurer/Bengin"
adenocarcinoma_folder = "/content/drive/MyDrive/model_2_types_cancer_bein_v2_structurer/adenocarcinoma"
large_cell_carcinoma_folder = "/content/drive/MyDrive/model_2_types_cancer_bein_v2_structurer/large.cell.carcinoma"
squamous_cell_carcinoma_folder = "/content/drive/MyDrive/model_2_types_cancer_bein_v2_structurer/squamous.cell.carcinoma"

# Fonction pour compter les fichiers dans un dossier
def count_images(folder_path):
    return len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

# Compter les images dans chaque sous-dossier
Bengin_count = count_images(Bengin_folder)
adenocarcinoma_count = count_images(adenocarcinoma_folder)
large_cell_carcinoma_count = count_images(large_cell_carcinoma_folder)
squamous_cell_carcinoma_count = count_images(squamous_cell_carcinoma_folder)

# Afficher le nombre d'images dans chaque dossier
print(f"Nombre d'images dans le dossier 'Bengin' : {Bengin_count}")
print(f"Nombre d'images dans le dossier 'adenocarcinoma' : {adenocarcinoma_count}")
print(f"Nombre d'images dans le dossier 'large.cell.carcinoma' : {large_cell_carcinoma_count}")
print(f"Nombre d'images dans le dossier 'squamous.cell.carcinoma' : {squamous_cell_carcinoma_count}")
# Out:
# Nombre d'images dans le dossier 'Bengin' : 340
# Nombre d'images dans le dossier 'adenocarcinoma' : 340
# Nombre d'images dans le dossier 'large.cell.carcinoma' : 340
# Nombre d'images dans le dossier 'squamous.cell.carcinoma' : 340

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/model_2_types_cancer_bein_v2_structurer",
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 1360 files belonging to 4 classes.

# %%
class_name = dataset.class_names
class_name
# Out:
# ['Bengin', 'adenocarcinoma', 'large.cell.carcinoma', 'squamous.cell.carcinoma']

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 224, 224, 3)
# [3 3 1 0 1 0 1 3 0 3 0 1 3 2 3 0 2 0 2 1 3 3 0 1 2 0 3 0 3 1 3 0]

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        ax.imshow(image_batch[i].numpy().astype('uint8'))
        ax.set_title(class_name[label_batch[i].numpy()])
        ax.axis("off")
plt.show()

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, test_split=0.1, val_split=0.1, shuffle=True, shuffle_size = 10000):
    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split*ds_size)
    val_size = int(val_split*ds_size)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 34

# %%
len(val_ds)
# Out:
# 4

# %%
len(test_ds)
# Out:
# 5

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    #layers.RandomRotation(0.2),
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 4
model = tf.keras.Sequential([
    layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),  # Spécifie la forme des données d'entrée
    resize_and_rescale,  # Redimensionnement et normalisation
    data_augmentation,   # Augmentation des données
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = 100,
    batch_size = 32,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 152s 397ms/step - accuracy: 0.4140 - loss: 2.1547 - val_accuracy: 0.6328 - val_loss: 0.7564
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 52s 55ms/step - accuracy: 0.7192 - loss: 0.6491 - val_accuracy: 0.7500 - val_loss: 0.6057
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.7914 - loss: 0.5012 - val_accuracy: 0.7031 - val_loss: 0.6259
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8098 - loss: 0.4740 - val_accuracy: 0.7812 - val_loss: 0.5182
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8321 - loss: 0.4311 - val_accuracy: 0.7812 - val_loss: 0.5647
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8762 - loss: 0.3473 - val_accuracy: 0.8594 - val_loss: 0.3496
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9142 - loss: 0.2426 - val_accuracy: 0.7812 - val_loss: 0.5444
# Epoch 8/100
# ...

# %%
model.evaluate(test_ds)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9765 - loss: 0.1566
# [0.24410589039325714, 0.9750000238418579]

# %%
#model.evaluate(test_ds)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9783 - loss: 0.1014
# [0.1746092587709427, 0.96875]

# %%
def predict_single(model, img, class_name):
    # Convertir l'image en tableau numpy et ajouter une dimension
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Ajouter une dimension (batch)

    # Faire des prédictions
    predictions = model.predict(img_array)
    predicted_class = class_name[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
def predict_dataset(model, dataset, class_names):
    y_true = []
    y_pred = []

    # Parcourir le dataset pour faire des prédictions
    for images, labels in dataset:
        predictions = model.predict(images)
        predicted_classes = np.argmax(predictions, axis=1)
        y_pred.extend(predicted_classes)
        y_true.extend(labels.numpy())  # Ajouter les étiquettes vraies

    return np.array(y_true), np.array(y_pred)

# %%
from sklearn.metrics import classification_report
import numpy as np

# Prédire sur le dataset de test
y_true, y_pred = predict_dataset(model, test_ds, class_name)

# Générer le rapport de classification
report = classification_report(y_true, y_pred, target_names=class_name)
print(report)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#                          precision    recall  f1-score   support
#
#                  Bengin       1.00      1.00      1.00        35
#          adenocarcinoma       0.96      0.98      0.97        45
#    large.cell.carcinoma       1.00      0.94      0.97        47
# squamous.cell.carcinoma       0.94      1.00      0.97        33
#
#                accuracy                           0.97       160
#               macro avg       0.97      0.98      0.98       160
#            weighted avg       0.98      0.97      0.97       160

# %%
import numpy as np
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img[i].numpy())
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    predicted_class = class_name[np.argmax(predictions[0])]
    confidence = round(100*(np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype('uint8'))

    predicted_class, confidence = predict(model, images)
    actual_class = class_name[labels[i]]

    plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

    plt.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
model.export("/content/drive/MyDrive/CT_model_2_v2")
# Out:
# Saved artifact at '/content/drive/MyDrive/CT_model_2_v2'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   139991059446448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269743296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988270146736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269131280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269128288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269132512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269274688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269274512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139988269271696: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
model.save("/content/drive/MyDrive/CT_model_2_v2.keras")

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 4
model = tf.keras.Sequential([
    layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),  # Spécifie la forme des données d'entrée
    resize_and_rescale,  # Redimensionnement et normalisation
    data_augmentation,   # Augmentation des données
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(128, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
model.fit(
    train_ds,
    epochs = 300,
    batch_size = 32,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.2731 - loss: 2.9501 - val_accuracy: 0.4062 - val_loss: 1.2271
# Epoch 2/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.3964 - loss: 1.1952 - val_accuracy: 0.2812 - val_loss: 1.1773
# Epoch 3/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.4499 - loss: 1.0950 - val_accuracy: 0.5312 - val_loss: 1.0428
# Epoch 4/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.3944 - loss: 1.0854 - val_accuracy: 0.5000 - val_loss: 0.9825
# Epoch 5/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - accuracy: 0.4897 - loss: 0.9504 - val_accuracy: 0.5625 - val_loss: 0.9083
# Epoch 6/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - accuracy: 0.5088 - loss: 0.9211 - val_accuracy: 0.5000 - val_loss: 0.8745
# Epoch 7/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.4881 - loss: 0.9326 - val_accuracy: 0.4688 - val_loss: 0.9026
# Epoch 8/500
# ...

# %%
model.evaluate(test_ds)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8854 - loss: 0.2957
# [0.2822607159614563, 0.8958333134651184]

# %%
from sklearn.metrics import classification_report
import numpy as np

# Prédire sur le dataset de test
y_true, y_pred = predict_dataset(model, test_ds, class_name)

# Générer le rapport de classification
report = classification_report(y_true, y_pred, target_names=class_name)
print(report)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
#                          precision    recall  f1-score   support
#
#                  Bengin       1.00      1.00      1.00        24
#          adenocarcinoma       0.75      0.92      0.83        26
#    large.cell.carcinoma       0.92      1.00      0.96        23
# squamous.cell.carcinoma       1.00      0.65      0.79        23
#
#                accuracy                           0.90        96
#               macro avg       0.92      0.89      0.89        96
#            weighted avg       0.91      0.90      0.89        96

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype('uint8'))

    predicted_class, confidence = predict(model, images)
    actual_class = class_name[labels[i]]

    plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

    plt.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 4
learnin_rate = 0.001
model = tf.keras.Sequential([
    layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),  # Spécifie la forme des données d'entrée
    resize_and_rescale,  # Redimensionnement et normalisation
    data_augmentation,   # Augmentation des données
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

# %%
model.compile(
    optimizer = ,
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
model.fit(
    train_ds,
    epochs = 300,
    batch_size = 32,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.3040 - loss: 1.3320 - val_accuracy: 0.3438 - val_loss: 1.1886
# Epoch 2/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.4192 - loss: 1.1248 - val_accuracy: 0.4375 - val_loss: 1.0675
# Epoch 3/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.4193 - loss: 1.1046 - val_accuracy: 0.3125 - val_loss: 1.1153
# Epoch 4/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.4549 - loss: 1.0547 - val_accuracy: 0.4375 - val_loss: 1.0448
# Epoch 5/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.4215 - loss: 1.0915 - val_accuracy: 0.5000 - val_loss: 1.0047
# Epoch 6/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.4742 - loss: 1.0630 - val_accuracy: 0.4375 - val_loss: 1.0082
# Epoch 7/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.4881 - loss: 1.0037 - val_accuracy: 0.5000 - val_loss: 0.9987
# Epoch 8/300
# ...

# %%
model.evaluate(test_ds)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7212 - loss: 0.5190
# [0.5039574503898621, 0.75]

# %%
from sklearn.metrics import classification_report
import numpy as np

# Prédire sur le dataset de test
y_true, y_pred = predict_dataset(model, test_ds, class_name)

# Générer le rapport de classification
report = classification_report(y_true, y_pred, target_names=class_name)
print(report)

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype('uint8'))

    predicted_class, confidence = predict(model, images)
    actual_class = class_name[labels[i]]

    plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

    plt.axis('off')
